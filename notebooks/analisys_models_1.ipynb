# %% [markdown]
# ## Анализ работы модели 1 с регуляцией и без
#
# ### Без регуляризации
#
# ```
# {
#         "model": "model_1.py",
#         "omega": [
#             0.8295579923781463,
#             0.12192011282524019,
#             -0.27366196030086126,
#             0.3206200196811857,
#             -0.004131824217314693,
#             -0.03998330663196729,
#             -0.910294705279984,
#             -0.8845141524506661
#         ],
#         "bias": 2.077350641957363,
#         "eta": 0.3300000000000002,
#         "Number of iterations": 1000,
#         "feature_names": [
#             "MedInc",
#             "HouseAge",
#             "AveRooms",
#             "AveBedrms",
#             "Population",
#             "AveOccup",
#             "Latitude",
#             "Longitude"
#         ],
#         "trained_on": "2026-02-05 15:17:44.120979",
#         "mse_on_train": 0.5232624469073837,
#         "mse_on_test": 0.5291402345397308
#     },
#     {
#         "model": "model_1.py",
#         "omega": [
#             0.8295579923781463,
#             0.12192011282524019,
#             -0.27366196030086126,
#             0.3206200196811857,
#             -0.004131824217314693,
#             -0.03998330663196729,
#             -0.910294705279984,
#             -0.8845141524506661
#         ],
#         "bias": 2.077350641957363,
#         "eta": 0.3400000000000002,
#         "Number of iterations": 1000,
#         "feature_names": [
#             "MedInc",
#             "HouseAge",
#             "AveRooms",
#             "AveBedrms",
#             "Population",
#             "AveOccup",
#             "Latitude",
#             "Longitude"
#         ],
#         "trained_on": "2026-02-05 15:17:44.638236",
#         "mse_on_train": 0.5232624469073837,
#         "mse_on_test": 0.5291402345397308
#     },
#     {
#         "model": "model_1.py",
#         "omega": [
#             0.8295579923781463,
#             0.12192011282524019,
#             -0.27366196030086126,
#             0.3206200196811857,
#             -0.004131824217314693,
#             -0.03998330663196729,
#             -0.910294705279984,
#             -0.8845141524506661
#         ],
#         "bias": 2.077350641957363,
#         "eta": 0.3500000000000002,
#         "Number of iterations": 1000,
#         "feature_names": [
#             "MedInc",
#             "HouseAge",
#             "AveRooms",
#             "AveBedrms",
#             "Population",
#             "AveOccup",
#             "Latitude",
#             "Longitude"
#         ],
#         "trained_on": "2026-02-05 15:17:45.131826",
#         "mse_on_train": 0.5232624469073837,
#         "mse_on_test": 0.5291402345397308
#     }
# ```
# ### С L1 регуляризатором
# ```
# {
#         "model": "model_1_l1.py",
#         "omega": [
#             0.652364008259434,
#             0.04298893463880449,
#             -0.055560310259660836,
#             -0.026092761481207566,
#             0.006871008300429124,
#             -0.03407466077700274,
#             0.0009063865052869914,
#             0.02411026206718763
#         ],
#         "bias": 2.077350641957364,
#         "eta": 0.15,
#         "Number of iterations": 1000,
#         "lm_l1": 0.3,
#         "feature_names": [
#             "MedInc",
#             "HouseAge",
#             "AveRooms",
#             "AveBedrms",
#             "Population",
#             "AveOccup",
#             "Latitude",
#             "Longitude"
#         ],
#         "trained_on": "2026-02-05 13:36:06.769906",
#         "mse_on_train": 0.9655164801975615,
#         "mse_on_test": 0.9435928700477998
#     },
#     {
#         "model": "model_1_l1.py",
#         "omega": [
#             0.7438094355964256,
#             0.14429033948299405,
#             -0.010383649202066986,
#             0.014338023792763057,
#             -0.005079434693585034,
#             -0.027335091996011463,
#             -0.2556660520521265,
#             -0.21780388116435298
#         ],
#         "bias": 2.0773506419573637,
#         "eta": 0.15,
#         "Number of iterations": 1000,
#         "lm_l1": 0.1,
#         "feature_names": [
#             "MedInc",
#             "HouseAge",
#             "AveRooms",
#             "AveBedrms",
#             "Population",
#             "AveOccup",
#             "Latitude",
#             "Longitude"
#         ],
#         "trained_on": "2026-02-05 13:37:00.265191",
#         "mse_on_train": 0.7470760154748594,
#         "mse_on_test": 0.7410561982319397
#     },
#     {
#         "model": "model_1_l1.py",
#         "omega": [
#             0.7105839684972628,
#             0.10973632260206151,
#             -0.036052704159828274,
#             0.028247673230270748,
#             -0.018995672773839702,
#             -0.0069968079670653695,
#             -0.015701833179414627,
#             -0.04312378128786791
#         ],
#         "bias": 2.077350641957364,
#         "eta": 0.15,
#         "Number of iterations": 1000,
#         "lm_l1": 0.2,
#         "feature_names": [
#             "MedInc",
#             "HouseAge",
#             "AveRooms",
#             "AveBedrms",
#             "Population",
#             "AveOccup",
#             "Latitude",
#             "Longitude"
#         ],
#         "trained_on": "2026-02-05 13:37:01.152908",
#         "mse_on_train": 0.8623760967463782,
#         "mse_on_test": 0.8527404239035482
#     }
# ```
#
# ### С L2 регуляризатором
#
# ```
# {
#         "model": "model_1_l2.py",
#         "omega": [
#             0.7809131265131526,
#             0.15506151244545446,
#             -0.14741261786297763,
#             0.17334008961089545,
#             0.00788775479335897,
#             -0.04053668261890072,
#             -0.5497528651132971,
#             -0.5180549725586299
#         ],
#         "bias": 2.0773506419573633,
#         "eta": 0.15,
#         "Number of iterations": 1000,
#         "lm_l2": 0.1,
#         "feature_names": [
#             "MedInc",
#             "HouseAge",
#             "AveRooms",
#             "AveBedrms",
#             "Population",
#             "AveOccup",
#             "Latitude",
#             "Longitude"
#         ],
#         "trained_on": "2026-02-05 00:05:16.046017",
#         "mse_on_train": 0.6094068293353677,
#         "mse_on_test": 0.6089950222234748
#     },
#     {
#         "model": "model_1_l2.py",
#         "omega": [
#             0.7350613334880075,
#             0.1604871932610794,
#             -0.07921315022745248,
#             0.0992593455289527,
#             0.010153048755155193,
#             -0.03881282025293699,
#             -0.40731055742935085,
#             -0.3725048380444919
#         ],
#         "bias": 2.0773506419573633,
#         "eta": 0.15,
#         "Number of iterations": 1000,
#         "lm_l2": 0.2,
#         "feature_names": [
#             "MedInc",
#             "HouseAge",
#             "AveRooms",
#             "AveBedrms",
#             "Population",
#             "AveOccup",
#             "Latitude",
#             "Longitude"
#         ],
#         "trained_on": "2026-02-05 00:05:16.565270",
#         "mse_on_train": 0.6617237608376206,
#         "mse_on_test": 0.657461396752124
#     },
#     {
#         "model": "model_1_l2.py",
#         "omega": [
#             0.6965734101818174,
#             0.1583746234761914,
#             -0.040003238966113346,
#             0.05777443033330531,
#             0.009864980083041706,
#             -0.0367573559353665,
#             -0.32921922876104914,
#             -0.29283237615494434
#         ],
#         "bias": 2.0773506419573637,
#         "eta": 0.15,
#         "Number of iterations": 1000,
#         "lm_l2": 0.30000000000000004,
#         "feature_names": [
#             "MedInc",
#             "HouseAge",
#             "AveRooms",
#             "AveBedrms",
#             "Population",
#             "AveOccup",
#             "Latitude",
#             "Longitude"
#         ],
#         "trained_on": "2026-02-05 00:05:17.099154",
#         "mse_on_train": 0.7012761345374485,
#         "mse_on_test": 0.6941571844779111
#     }
# ```

# %% [markdown]
# ## Выводы
#
# Базовая линейная модель имеет наименьший средний эмпирический риск. MSE на L1 и L2 регуляризации возрастает пропорционально росту коэфицента lm_l1, lm_l2 соответственно, что превышает MSE базовой модели.
